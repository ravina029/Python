# %%
import pandas as pd

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=sns.load_dataset('iris')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
#seaborn line plot
sns.lineplot(x="sepal_length",y='petal_length',data=df)
sns.lineplot(x="sepal_length",y='sepal_width',data=df)
plt.show()

# %%
df=sns.load_dataset('tips')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.lineplot(data=df,x='day',y='tip',hue='smoker',style='sex',palette='flare')
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
df=sns.load_dataset('titanic')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.barplot(data=df,x='who',y='fare',color='blue')
# Out:
# <Axes: xlabel='who', ylabel='fare'>

# %%
sns.barplot(data=df,x='who',y='fare',color='blue',hue='survived')
# Out:
# <Axes: xlabel='who', ylabel='fare'>

# %%
sns.barplot(data=df,x='who',y='fare',color='blue',hue='sex')
# Out:
# <Axes: xlabel='who', ylabel='fare'>

# %%
sns.barplot(data=df,x='who',y='fare',color='blue',hue='who',palette='spring')
# Out:
# <Axes: xlabel='who', ylabel='fare'>

# %%
sns.barplot(data=df,x='who',y='fare',color='blue',hue='survived',saturation=0.7)
# Out:
# <Axes: xlabel='who', ylabel='fare'>

# %%
sns.barplot(data=df,y='who',x='fare',hue='survived')
# Out:
# <Axes: xlabel='fare', ylabel='who'>

# %%
sns.barplot(data=df,y='who',x='fare',hue='survived',ci=False)
# Out:
# /var/folders/3t/5qtlv2451k3fkqv9ls22lmg00000gn/T/ipykernel_50056/2100761518.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   sns.barplot(data=df,y='who',x='fare',hue='survived',ci=False)
# <Axes: xlabel='fare', ylabel='who'>

# %%
from numpy import mean
sns.barplot(data=df,x='who',y='fare',estimator=mean)
# Out:
# <Axes: xlabel='who', ylabel='fare'>

# %%
from numpy import median 
sns.barplot(data=df,x='who',y='fare',estimator=median)
# Out:
# <Axes: xlabel='who', ylabel='fare'>

# %%
sns.barplot(data=df,x='who',y='fare',estimator=median,facecolor=[1,1,1,0],edgecolor='0.3')
# Out:
# <Axes: xlabel='who', ylabel='fare'>

# %%
sns.barplot(data=df,x='who',y='fare',estimator=median,facecolor=[1,1,1,0.5],edgecolor='0.3',order=['child','woman','man'])
# Out:
# <Axes: xlabel='who', ylabel='fare'>

# %% [markdown]
# # Histogram

# %%
df=sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.histplot(x='total_bill',data=df)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.histplot(x='total_bill',data=df,discrete='false') #this gives the actual data
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.histplot(x='total_bill',data=df,discrete='false',hue='sex',palette='spring') #this gives the actual data
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.histplot(x='total_bill',data=df,discrete='false',kde=True,edgecolor='r') #this gives the actual data
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.scatterplot(x='total_bill',y='tip',data=df,hue='sex',size='smoker',marker='*') #this gives the actual data
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x='total_bill',y='tip',data=df,hue='sex',size='smoker',alpha=0.5) #this gives the actual data
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
import numpy as np
import random

# %%
x=np.random.randint(10,100,(10,10))

# %%
sns.heatmap(x)
# Out:
# <Axes: >

# %%
sns.heatmap(x,cmap='viridis')
# Out:
# <Axes: >

# %%
sns.heatmap(x,cmap='viridis',alpha=0.7)
# Out:
# <Axes: >

# %%
sns.heatmap(x,cmap='viridis',annot=True)
# Out:
# <Axes: >

# %%
sns.heatmap(x,cmap='viridis',annot=True,cbar=False)
# Out:
# <Axes: >

# %%
sns.heatmap(x,cmap='viridis',annot=True,cbar=False,xticklabels=False,yticklabels=False)
# Out:
# <Axes: >

# %% [markdown]
# # Countplot

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.countplot(x='sex', data=df)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.countplot(x='smoker', data=df,hue='sex')
# Out:
# <Axes: xlabel='smoker', ylabel='count'>

# %%
sns.countplot(y='sex', data=df,palette='spring')
# Out:
# <Axes: xlabel='count', ylabel='sex'>

# %%
sns.countplot(y='sex', data=df,palette='spring',saturation=0.2)
# Out:
# <Axes: xlabel='count', ylabel='sex'>

# %% [markdown]
# # violin plot

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.violinplot(x='tip',data=df)
# Out:
# <Axes: xlabel='tip'>

# %%
sns.violinplot(x=df['total_bill'])
# Out:
# <Axes: xlabel='total_bill'>

# %%
sns.violinplot(x=df['sex'],y=df['tip'])
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %%
sns.violinplot(x=df['sex'],y=df['tip'],hue=df['day'])
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %%
sns.violinplot(x=df['sex'],y=df['tip'],hue=df['day'],palette='viridis')
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %%
sns.violinplot(y=df['sex'],x=df['tip'],hue=df['day'])
# Out:
# <Axes: xlabel='tip', ylabel='sex'>

# %%
sns.violinplot(x=df['day'],y=df['tip'],hue=df['sex'],split=True)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.violinplot(y=df['sex'],x=df['tip'],hue=df['day'],saturation=0.5)
# Out:
# <Axes: xlabel='tip', ylabel='sex'>

# %%
sns.violinplot(x=df['sex'],y=df['tip'],order=['Female','Male'])
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %%
sns.boxplot(x='tip',data=df)
# Out:
# <Axes: xlabel='tip'>

# %%
sns.boxplot(x='total_bill',data=df)  #total_bill	tip	sex	smoker	day	time	size
# Out:
# <Axes: xlabel='total_bill'>

# %%
sns.boxplot(x='sex',y='tip',data=df)
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %%
sns.boxplot(x='sex',y='total_bill',data=df,hue='smoker',linewidth=3)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
sns.boxplot(x='sex',y='total_bill',data=df,hue='smoker',linewidth=3,orient='v')
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
sns.set(style='whitegrid')
sns.boxplot(x='sex',y='total_bill',data=df,hue='smoker',linewidth=3)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
sns.pairplot(df,height=2,hue='sex')

# %%
sns.pairplot(df,height=2,hue='sex',diag_kind='hist')

# %%
sns.pairplot(df,height=2,hue='sex',diag_kind='kde')

# %%
sns.pairplot(df,height=2,hue='sex',diag_kind='hist',plot_kws={'edgecolor':'black'})

# %% [markdown]
# # Catplot

# %%
sns.catplot(x='sex',y='tip',data=df)

# %%
sns.catplot(x='sex',y='tip',data=df,kind='bar')

# %%
sns.catplot(x='sex',y='tip',data=df,kind='violin')

# %%
sns.catplot(x='sex',y='tip',data=df,palette='spring',hue='smoker')

# %%
sns.kdeplot(x='tip',data=df)
# Out:
# <Axes: xlabel='tip', ylabel='Density'>

# %%
sns.kdeplot(x='tip',y='total_bill',data=df,hue='sex')
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %%
sns.kdeplot(x='tip',y='total_bill',data=df,shade=True)
# Out:
# /var/folders/3t/5qtlv2451k3fkqv9ls22lmg00000gn/T/ipykernel_50056/3958501215.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(x='tip',y='total_bill',data=df,shade=True)
# <Axes: xlabel='tip', ylabel='total_bill'>
